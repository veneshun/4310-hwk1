# %%
import numpy as np
import pandas as pd
import regex as re

import seaborn
from matplotlib import pyplot as plt

import duckdb, sqlalchemy

import array as arr

# %%
# %load_ext sql

# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %sql duckdb:///:memory:

# %%
trees_df = pd.read_csv('Street_Tree_List-FILTERED.csv')

# %%
trees_df = trees_df.rename(columns = {'qSpecies' : 'scientific_name'})

trees_df.insert(5, 'common_name', (trees_df['scientific_name'].str.partition(' :: ')[2]).astype(str))
trees_df['scientific_name'] = (trees_df['scientific_name'].str.partition(' ::')[0]).astype(str)


trees_df.insert(3, 'genus', (trees_df['scientific_name'].str.partition(' ')[0]).astype(str))
trees_df.insert(4, 'species', (trees_df['scientific_name'].str.partition(' ')[2]).astype(str))


trees_df["PlantDate"] = pd.to_datetime(trees_df["PlantDate"])

trees_df.insert(10, 'Year', trees_df['PlantDate'].dt.year)
trees_df.insert(11, 'Month', trees_df['PlantDate'].dt.month_name())

trees_df
# Out:
#        TreeID    qLegalStatus                        scientific_name  \
# 0      200311  DPW Maintained  Liquidambar styraciflua 'Rotundiloba'
# 1       10425  DPW Maintained               Schinus terebinthifolius
# 2       43163  DPW Maintained                     Acacia melanoxylon
# 3      188921  DPW Maintained                   Callistemon citrinus
# 4         643  DPW Maintained                       Ficus microcarpa
# ...       ...             ...                                    ...
# 37113  141243  DPW Maintained                   Magnolia grandiflora
# 37114  203553  DPW Maintained                        Agonis flexuosa
# 37115   61778  DPW Maintained                     Eriobotrya deflexa
# 37116  190242  DPW Maintained    Ficus microcarpa nitida 'Green Gem'
# 37117  192307  DPW Maintained                           Fraxinus spp
#
#              genus                        species              qAddress  \
# 0      Liquidambar      styraciflua 'Rotundiloba'          300 Spear St
# 1          Schinus               terebinthifolius        1419 Haight St
# 2           Acacia                    melanoxylon        222 Madison St
# 3      Callistemon                       citrinus          2001 25th St
# 4            Ficus                     microcarpa          3224 24th St
# ...            ...                            ...                   ...
# 37113     Magnolia                    grandiflora   31 COMMONWEALTH AVE
# 37114       Agonis                       flexuosa         259 Faxon Ave
# 37115   Eriobotrya                        deflexa          2219 24th St
# 37116        Ficus  microcarpa nitida 'Green Gem'  60 New Montgomery St
# 37117     Fraxinus                            spp        100 De Haro St
#
#        SiteOrder                         common_name  \
# 0            9.0                  Roundleaf sweetgum
# 1            2.0                    Brazilian Pepper
# 2            1.0                    Blackwood Acacia
# 3           16.0                   Lemon Bottlebrush
# 4            1.0                      Chinese Banyan
# ...          ...                                 ...
# 37113        1.0                   Southern Magnolia
# 37114        1.0                   Peppermint Willow
# 37115        1.0                       Bronze Loquat
# 37116        3.0  Indian Laurel Fig Tree 'Green Gem'
# 37117        1.0                             Ash Spp
#
#                             qSiteInfo qCaretaker    Year    Month  PlantDate  \
# 0          Sidewalk: Curb side : Yard    Private     NaN      NaN        NaT
# 1        Sidewalk: Curb side : Cutout        DPW     NaN      NaN        NaT
# 2        Sidewalk: Curb side : Cutout    Private  2000.0     July 2000-07-11
# 3      Sidewalk: Property side : Yard    Private     NaN      NaN        NaT
# 4        Sidewalk: Curb side : Cutout    Private     NaN      NaN        NaT
# ...                               ...        ...     ...      ...        ...
# 37113      Sidewalk: Curb side : Yard    Private     NaN      NaN        NaT
# 37114    Sidewalk: Curb side : Cutout    Private     NaN      NaN        NaT
# 37115    Sidewalk: Curb side : Cutout    Private  1985.0  January 1985-01-22
# 37116       Sidewalk: Curb side : Pot    Private     NaN      NaN        NaT
# 37117    Sidewalk: Curb side : Cutout    Private     NaN      NaN        NaT
#
#        DBH   PlotSize   Latitude   Longitude
# 0        5        NaN  37.789193 -122.390006
# 1       90        3x3  37.770094 -122.445693
# 2        8        NaN  37.726036 -122.422690
# 3        6  Width 8ft  37.751955 -122.399482
# 4       18        3x3  37.752398 -122.416772
# ...    ...        ...        ...         ...
# 37113   10  Width 0ft  37.785434 -122.455909
# 37114    2  Width 3ft  37.719278 -122.460296
# 37115   13        NaN  37.753203 -122.401882
# 37116    2  Width 3ft  37.788459 -122.401854
# 37117   12  Width 4ft  37.767303 -122.401956
#
# [37118 rows x 17 columns]

# %%
trees_df.to_csv('trees.csv')

# %%
# %sql genus_df << SELECT genus, COUNT(*) as count \
FROM trees_df GROUP BY genus, \
ORDER BY COUNT(*) ASC;
# Out:
# Returning data to local variable genus_df

# %%
genus_df.insert(2, 'percentage', (genus_df['count']/37118)*100)

# %%
genus_df.to_csv('genus.csv')

# %%
# %sql species_df << SELECT scientific_name, common_name, genus, COUNT(scientific_name) as count \
FROM trees_df GROUP BY scientific_name, common_name, genus \
ORDER BY COUNT(scientific_name) DESC;
# Out:
# Returning data to local variable species_df

# %%
species_df.insert(3, 'percentage', (species_df['count']/37118)*100)

# %%
species_df
# Out:
#                   scientific_name                       common_name  \
# 0            Platanus x hispanica            Sycamore: London Plane
# 1            Metrosideros excelsa             New Zealand Xmas Tree
# 2           Lophostemon confertus                      Brisbane Box
# 3           Pittosporum undulatum                     Victorian Box
# 4           Tristaniopsis laurina                      Swamp Myrtle
# ..                            ...                               ...
# 414               Juglans hindsii           Walnut: Black (n.calif)
# 415              Metrosideros spp
# 416               Acacia dealbata                     Silver Wattle
# 417              Phoenix rupicola                   Cliff date palm
# 418  Pyrus calleryana 'Cleveland'  Ornamental Pear Tree 'Cleveland'
#
#              genus  percentage  count
# 0         Platanus    7.093593   2633
# 1     Metrosideros    5.218492   1937
# 2      Lophostemon    4.652729   1727
# 3      Pittosporum    4.496471   1669
# 4    Tristaniopsis    4.248613   1577
# ..             ...         ...    ...
# 414        Juglans    0.002694      1
# 415   Metrosideros    0.002694      1
# 416         Acacia    0.002694      1
# 417        Phoenix    0.002694      1
# 418          Pyrus    0.002694      1
#
# [419 rows x 5 columns]

# %%
species_df.to_csv('species.csv')

# %%
common_trees = species_df[species_df['percentage'] >= 1]

# %%
common_trees = common_trees['scientific_name'].tolist()

print(common_trees)
print(len(common_trees))
# Out:
# ['Platanus x hispanica', 'Metrosideros excelsa', 'Lophostemon confertus', 'Pittosporum undulatum', 'Tristaniopsis laurina', "Ficus microcarpa nitida 'Green Gem'", 'Magnolia grandiflora', 'Prunus cerasifera', "Arbutus 'Marina'", "Prunus serrulata 'Kwanzan'", 'Acacia melanoxylon', 'Olea europaea', 'Corymbia ficifolia', 'Maytenus boaria', 'Callistemon citrinus', 'Ginkgo biloba', 'Pyrus calleryana', 'Ulmus parvifolia', 'Ligustrum lucidum', 'Eriobotrya deflexa', 'Pinus radiata', 'Pyrus kawakamii', 'Cordyline australis']
# 23

# %%
most_common_trees_df = trees_df[trees_df["scientific_name"].isin(common_trees)]

most_common_trees_df
# Out:
#        TreeID    qLegalStatus                      scientific_name  \
# 2       43163  DPW Maintained                   Acacia melanoxylon
# 3      188921  DPW Maintained                 Callistemon citrinus
# 6      133773  DPW Maintained                 Platanus x hispanica
# 8      209974  DPW Maintained                 Metrosideros excelsa
# 9        9999  DPW Maintained  Ficus microcarpa nitida 'Green Gem'
# ...       ...             ...                                  ...
# 37111   54849  DPW Maintained                    Prunus cerasifera
# 37112   21647  DPW Maintained                 Magnolia grandiflora
# 37113  141243  DPW Maintained                 Magnolia grandiflora
# 37115   61778  DPW Maintained                   Eriobotrya deflexa
# 37116  190242  DPW Maintained  Ficus microcarpa nitida 'Green Gem'
#
#               genus                        species              qAddress  \
# 2            Acacia                    melanoxylon        222 Madison St
# 3       Callistemon                       citrinus          2001 25th St
# 6          Platanus                    x hispanica         2460 Scott St
# 8      Metrosideros                        excelsa       634 Miramar Ave
# 9             Ficus  microcarpa nitida 'Green Gem'       126 Guerrero St
# ...             ...                            ...                   ...
# 37111        Prunus                     cerasifera         2076 Grove St
# 37112      Magnolia                    grandiflora        1660 Sutter St
# 37113      Magnolia                    grandiflora   31 COMMONWEALTH AVE
# 37115    Eriobotrya                        deflexa          2219 24th St
# 37116         Ficus  microcarpa nitida 'Green Gem'  60 New Montgomery St
#
#        SiteOrder                         common_name  \
# 2            1.0                    Blackwood Acacia
# 3           16.0                   Lemon Bottlebrush
# 6            1.0              Sycamore: London Plane
# 8            1.0               New Zealand Xmas Tree
# 9            1.0  Indian Laurel Fig Tree 'Green Gem'
# ...          ...                                 ...
# 37111        1.0                         Cherry Plum
# 37112        2.0                   Southern Magnolia
# 37113        1.0                   Southern Magnolia
# 37115        1.0                       Bronze Loquat
# 37116        3.0  Indian Laurel Fig Tree 'Green Gem'
#
#                             qSiteInfo qCaretaker    Year    Month  PlantDate  \
# 2        Sidewalk: Curb side : Cutout    Private  2000.0     July 2000-07-11
# 3      Sidewalk: Property side : Yard    Private     NaN      NaN        NaT
# 6        Sidewalk: Curb side : Cutout    Private     NaN      NaN        NaT
# 8        Sidewalk: Curb side : Cutout    Private     NaN      NaN        NaT
# 9        Sidewalk: Curb side : Cutout        DPW     NaN      NaN        NaT
# ...                               ...        ...     ...      ...        ...
# 37111    Sidewalk: Curb side : Cutout    Private  1989.0    April 1989-04-03
# 37112    Sidewalk: Curb side : Cutout    Private     NaN      NaN        NaT
# 37113      Sidewalk: Curb side : Yard    Private     NaN      NaN        NaT
# 37115    Sidewalk: Curb side : Cutout    Private  1985.0  January 1985-01-22
# 37116       Sidewalk: Curb side : Pot    Private     NaN      NaN        NaT
#
#        DBH   PlotSize   Latitude   Longitude
# 2        8        NaN  37.726036 -122.422690
# 3        6  Width 8ft  37.751955 -122.399482
# 6       16  Width 4ft  37.792467 -122.439533
# 8        6  Width 3ft  37.728313 -122.458106
# 9       18       5x12  37.769212 -122.424656
# ...    ...        ...        ...         ...
# 37111    8        NaN  37.774373 -122.450701
# 37112   12        3X2  37.786868 -122.427688
# 37113   10  Width 0ft  37.785434 -122.455909
# 37115   13        NaN  37.753203 -122.401882
# 37116    2  Width 3ft  37.788459 -122.401854
#
# [23350 rows x 17 columns]

# %%
most_common_trees_df.to_csv('commonfull.csv')

# %%
common_trees_df = species_df[species_df['percentage'] >= 2.1]

# %%
common_trees_df.to_csv('common.csv')

# %%
average_dbh_df = most_common_trees_df.groupby(['scientific_name', 'common_name'])['DBH'].mean()

average_dbh_df.reset_index(name='avg_dbh')
average_dbh_df = average_dbh_df.round(2)

# %%
most_planted_month_df = most_common_trees_df.groupby(['scientific_name', 'common_name'])['Month'].apply(lambda x: pd.Series.mode(x)[0])

most_planted_month_df.reset_index(name='month')
# Out:
#                         scientific_name                         common_name  \
# 0                    Acacia melanoxylon                    Blackwood Acacia
# 1                      Arbutus 'Marina'              Hybrid Strawberry Tree
# 2                  Callistemon citrinus                   Lemon Bottlebrush
# 3                   Cordyline australis                        Dracena Palm
# 4                    Corymbia ficifolia                   Red Flowering Gum
# 5                    Eriobotrya deflexa                       Bronze Loquat
# 6   Ficus microcarpa nitida 'Green Gem'  Indian Laurel Fig Tree 'Green Gem'
# 7                         Ginkgo biloba                     Maidenhair Tree
# 8                     Ligustrum lucidum                       Glossy Privet
# 9                 Lophostemon confertus                        Brisbane Box
# 10                 Magnolia grandiflora                   Southern Magnolia
# 11                      Maytenus boaria                              Mayten
# 12                 Metrosideros excelsa               New Zealand Xmas Tree
# 13                        Olea europaea                          Olive Tree
# 14                        Pinus radiata                       Monterey Pine
# 15                Pittosporum undulatum                       Victorian Box
# 16                 Platanus x hispanica              Sycamore: London Plane
# 17                    Prunus cerasifera                         Cherry Plum
# 18           Prunus serrulata 'Kwanzan'            Kwanzan Flowering Cherry
# 19                     Pyrus calleryana                     Ornamental Pear
# 20                      Pyrus kawakamii                      Evergreen Pear
# 21                Tristaniopsis laurina                        Swamp Myrtle
# 22                     Ulmus parvifolia                         Chinese Elm
#
#         month
# 0        June
# 1       March
# 2        July
# 3       March
# 4       March
# 5    February
# 6        June
# 7       March
# 8   September
# 9    February
# 10      March
# 11        May
# 12    January
# 13      March
# 14      March
# 15        May
# 16    October
# 17       July
# 18   February
# 19      March
# 20      March
# 21      March
# 22        May

# %%
caretakers_df = most_common_trees_df.groupby(['scientific_name', 'common_name'])['qCaretaker'].apply(pd.Series.mode)

caretakers_df.reset_index(name='common_caretaker')
# Out:
#                         scientific_name                         common_name  \
# 0                    Acacia melanoxylon                    Blackwood Acacia
# 1                      Arbutus 'Marina'              Hybrid Strawberry Tree
# 2                  Callistemon citrinus                   Lemon Bottlebrush
# 3                   Cordyline australis                        Dracena Palm
# 4                    Corymbia ficifolia                   Red Flowering Gum
# 5                    Eriobotrya deflexa                       Bronze Loquat
# 6   Ficus microcarpa nitida 'Green Gem'  Indian Laurel Fig Tree 'Green Gem'
# 7                         Ginkgo biloba                     Maidenhair Tree
# 8                     Ligustrum lucidum                       Glossy Privet
# 9                 Lophostemon confertus                        Brisbane Box
# 10                 Magnolia grandiflora                   Southern Magnolia
# 11                      Maytenus boaria                              Mayten
# 12                 Metrosideros excelsa               New Zealand Xmas Tree
# 13                        Olea europaea                          Olive Tree
# 14                        Pinus radiata                       Monterey Pine
# 15                Pittosporum undulatum                       Victorian Box
# 16                 Platanus x hispanica              Sycamore: London Plane
# 17                    Prunus cerasifera                         Cherry Plum
# 18           Prunus serrulata 'Kwanzan'            Kwanzan Flowering Cherry
# 19                     Pyrus calleryana                     Ornamental Pear
# 20                      Pyrus kawakamii                      Evergreen Pear
# 21                Tristaniopsis laurina                        Swamp Myrtle
# 22                     Ulmus parvifolia                         Chinese Elm
#
#     level_2 common_caretaker
# 0         0          Private
# 1         0          Private
# 2         0          Private
# 3         0          Private
# 4         0          Private
# 5         0          Private
# 6         0          Private
# 7         0          Private
# 8         0          Private
# 9         0          Private
# 10        0          Private
# 11        0          Private
# 12        0          Private
# 13        0          Private
# 14        0          Private
# 15        0          Private
# 16        0          Private
# 17        0          Private
# 18        0          Private
# 19        0          Private
# 20        0          Private
# 21        0          Private
# 22        0          Private

# %%
details_df = pd.merge(average_dbh_df, most_planted_month_df, how="inner", on=['scientific_name', 'common_name'])

details_df
# Out:
#                                                                           DBH  \
# scientific_name                     common_name
# Acacia melanoxylon                  Blackwood Acacia                    15.86
# Arbutus 'Marina'                    Hybrid Strawberry Tree               5.82
# Callistemon citrinus                Lemon Bottlebrush                    9.01
# Cordyline australis                 Dracena Palm                         9.30
# Corymbia ficifolia                  Red Flowering Gum                   19.65
# Eriobotrya deflexa                  Bronze Loquat                        6.14
# Ficus microcarpa nitida 'Green Gem' Indian Laurel Fig Tree 'Green Gem'  14.46
# Ginkgo biloba                       Maidenhair Tree                      5.61
# Ligustrum lucidum                   Glossy Privet                        9.87
# Lophostemon confertus               Brisbane Box                         8.14
# Magnolia grandiflora                Southern Magnolia                    7.38
# Maytenus boaria                     Mayten                               8.58
# Metrosideros excelsa                New Zealand Xmas Tree               11.53
# Olea europaea                       Olive Tree                           7.55
# Pinus radiata                       Monterey Pine                       24.31
# Pittosporum undulatum               Victorian Box                        9.81
# Platanus x hispanica                Sycamore: London Plane              13.69
# Prunus cerasifera                   Cherry Plum                          5.92
# Prunus serrulata 'Kwanzan'          Kwanzan Flowering Cherry             5.82
# Pyrus calleryana                    Ornamental Pear                      5.74
# Pyrus kawakamii                     Evergreen Pear                       6.76
# Tristaniopsis laurina               Swamp Myrtle                         5.10
# Ulmus parvifolia                    Chinese Elm                         13.57
#
#                                                                             Month
# scientific_name                     common_name
# Acacia melanoxylon                  Blackwood Acacia                         June
# Arbutus 'Marina'                    Hybrid Strawberry Tree                  March
# Callistemon citrinus                Lemon Bottlebrush                        July
# Cordyline australis                 Dracena Palm                            March
# Corymbia ficifolia                  Red Flowering Gum                       March
# Eriobotrya deflexa                  Bronze Loquat                        February
# Ficus microcarpa nitida 'Green Gem' Indian Laurel Fig Tree 'Green Gem'       June
# Ginkgo biloba                       Maidenhair Tree                         March
# Ligustrum lucidum                   Glossy Privet                       September
# Lophostemon confertus               Brisbane Box                         February
# Magnolia grandiflora                Southern Magnolia                       March
# Maytenus boaria                     Mayten                                    May
# Metrosideros excelsa                New Zealand Xmas Tree                 January
# Olea europaea                       Olive Tree                              March
# Pinus radiata                       Monterey Pine                           March
# Pittosporum undulatum               Victorian Box                             May
# Platanus x hispanica                Sycamore: London Plane                October
# Prunus cerasifera                   Cherry Plum                              July
# Prunus serrulata 'Kwanzan'          Kwanzan Flowering Cherry             February
# Pyrus calleryana                    Ornamental Pear                         March
# Pyrus kawakamii                     Evergreen Pear                          March
# Tristaniopsis laurina               Swamp Myrtle                            March
# Ulmus parvifolia                    Chinese Elm                               May

# %%
details_df = pd.merge(details_df, caretakers_df, how="inner", on=['scientific_name', 'common_name'])
details_df = details_df.rename(columns = {'qCaretaker' : 'common_caretaker'})

details_df = details_df.head(n=12)

details_df
# Out:
#                                                                           DBH  \
# scientific_name                     common_name
# Acacia melanoxylon                  Blackwood Acacia                    15.86
# Arbutus 'Marina'                    Hybrid Strawberry Tree               5.82
# Callistemon citrinus                Lemon Bottlebrush                    9.01
# Cordyline australis                 Dracena Palm                         9.30
# Corymbia ficifolia                  Red Flowering Gum                   19.65
# Eriobotrya deflexa                  Bronze Loquat                        6.14
# Ficus microcarpa nitida 'Green Gem' Indian Laurel Fig Tree 'Green Gem'  14.46
# Ginkgo biloba                       Maidenhair Tree                      5.61
# Ligustrum lucidum                   Glossy Privet                        9.87
# Lophostemon confertus               Brisbane Box                         8.14
# Magnolia grandiflora                Southern Magnolia                    7.38
# Maytenus boaria                     Mayten                               8.58
#
#                                                                             Month  \
# scientific_name                     common_name
# Acacia melanoxylon                  Blackwood Acacia                         June
# Arbutus 'Marina'                    Hybrid Strawberry Tree                  March
# Callistemon citrinus                Lemon Bottlebrush                        July
# Cordyline australis                 Dracena Palm                            March
# Corymbia ficifolia                  Red Flowering Gum                       March
# Eriobotrya deflexa                  Bronze Loquat                        February
# Ficus microcarpa nitida 'Green Gem' Indian Laurel Fig Tree 'Green Gem'       June
# Ginkgo biloba                       Maidenhair Tree                         March
# Ligustrum lucidum                   Glossy Privet                       September
# Lophostemon confertus               Brisbane Box                         February
# Magnolia grandiflora                Southern Magnolia                       March
# Maytenus boaria                     Mayten                                    May
#
#                                                                        common_caretaker
# scientific_name                     common_name
# Acacia melanoxylon                  Blackwood Acacia                            Private
# Arbutus 'Marina'                    Hybrid Strawberry Tree                      Private
# Callistemon citrinus                Lemon Bottlebrush                           Private
# Cordyline australis                 Dracena Palm                                Private
# Corymbia ficifolia                  Red Flowering Gum                           Private
# Eriobotrya deflexa                  Bronze Loquat                               Private
# Ficus microcarpa nitida 'Green Gem' Indian Laurel Fig Tree 'Green Gem'          Private
# Ginkgo biloba                       Maidenhair Tree                             Private
# Ligustrum lucidum                   Glossy Privet                               Private
# Lophostemon confertus               Brisbane Box                                Private
# Magnolia grandiflora                Southern Magnolia                           Private
# Maytenus boaria                     Mayten                                      Private

# %%
details_df.to_csv('species_averages.csv')

# %%
common_genus = genus_df[genus_df['percentage'] >= 1]
common_genus = common_genus['genus'].tolist()

print(common_genus)
print(len(common_genus))
# Out:
# ['Cordyline', 'Cupressus', 'Melaleuca', 'Ligustrum', 'Eriobotrya', 'Acer', 'Eucalyptus', 'Pinus', 'Ginkgo', 'Maytenus', 'Ulmus', 'Corymbia', 'Callistemon', 'Olea', 'Acacia', 'Pyrus', 'Arbutus', 'Lophostemon', 'Magnolia', 'Tristaniopsis', 'Metrosideros', 'Pittosporum', 'Ficus', 'Platanus', 'Prunus']
# 25

# %%
common_genus_df = genus_df[genus_df['percentage'] >= 1]
common_genus_df = common_genus_df.rename(columns = {'genus' : 'name'})

common_genus_df.insert(2, 'Type', value="genus")
common_genus_df.insert(3, 'genus', value=common_genus_df['name'])

# %%
genus_species_df = species_df[species_df['genus'].isin(common_genus)]
genus_species_df.reset_index
# Out:
# <bound method DataFrame.reset_index of                   scientific_name                       common_name  \
# 0            Platanus x hispanica            Sycamore: London Plane
# 1            Metrosideros excelsa             New Zealand Xmas Tree
# 2           Lophostemon confertus                      Brisbane Box
# 3           Pittosporum undulatum                     Victorian Box
# 4           Tristaniopsis laurina                      Swamp Myrtle
# ..                            ...                               ...
# 410                Acer japonicum                    Japanese Maple
# 411               Pinus torreyana                       Torrey Pine
# 415              Metrosideros spp
# 416               Acacia dealbata                     Silver Wattle
# 418  Pyrus calleryana 'Cleveland'  Ornamental Pear Tree 'Cleveland'
#
#              genus  percentage  count
# 0         Platanus    7.093593   2633
# 1     Metrosideros    5.218492   1937
# 2      Lophostemon    4.652729   1727
# 3      Pittosporum    4.496471   1669
# 4    Tristaniopsis    4.248613   1577
# ..             ...         ...    ...
# 410           Acer    0.002694      1
# 411          Pinus    0.002694      1
# 415   Metrosideros    0.002694      1
# 416         Acacia    0.002694      1
# 418          Pyrus    0.002694      1
#
# [174 rows x 5 columns]>

# %%
# common_species_df = species_df[species_df['percentage'] >= 1]
common_species_df = genus_species_df.rename(columns = {'scientific_name' : 'name'})

common_species_df.insert(2, 'Type', value="species")

# %%
print(common_species_df)
# Out:
#                              name                       common_name     Type  \
# 0            Platanus x hispanica            Sycamore: London Plane  species
# 1            Metrosideros excelsa             New Zealand Xmas Tree  species
# 2           Lophostemon confertus                      Brisbane Box  species
# 3           Pittosporum undulatum                     Victorian Box  species
# 4           Tristaniopsis laurina                      Swamp Myrtle  species
# ..                            ...                               ...      ...
# 410                Acer japonicum                    Japanese Maple  species
# 411               Pinus torreyana                       Torrey Pine  species
# 415              Metrosideros spp                                    species
# 416               Acacia dealbata                     Silver Wattle  species
# 418  Pyrus calleryana 'Cleveland'  Ornamental Pear Tree 'Cleveland'  species
#
#              genus  percentage  count
# 0         Platanus    7.093593   2633
# 1     Metrosideros    5.218492   1937
# 2      Lophostemon    4.652729   1727
# 3      Pittosporum    4.496471   1669
# 4    Tristaniopsis    4.248613   1577
# ..             ...         ...    ...
# 410           Acer    0.002694      1
# 411          Pinus    0.002694      1
# 415   Metrosideros    0.002694      1
# 416         Acacia    0.002694      1
# 418          Pyrus    0.002694      1
#
# [174 rows x 6 columns]

# %%
common_genus_df.to_csv('common_genus.csv')
common_species_df.to_csv('common_species.csv')

# %%
nodes_df = pd.concat([common_genus_df, common_species_df], keys=['genus', 'species'], ignore_index=True)
nodes_df = nodes_df.drop(nodes_df.index[[1, 2, 4, 6, 7, 8]])
nodes_df.reset_index(drop=True, inplace=True)

# %%
nodes_df.insert(0, 'id', value=nodes_df.index + 1)
# nodes_df = nodes_df.set_index('genus')

nodes_df
# Out:
#       id                          name  count     Type         genus  \
# 0      1                     Cordyline    373    genus     Cordyline
# 1      2                     Ligustrum    518    genus     Ligustrum
# 2      3                          Acer    532    genus          Acer
# 3      4                      Maytenus    766    genus      Maytenus
# 4      5                         Ulmus    800    genus         Ulmus
# ..   ...                           ...    ...      ...           ...
# 188  189                Acer japonicum      1  species          Acer
# 189  190               Pinus torreyana      1  species         Pinus
# 190  191              Metrosideros spp      1  species  Metrosideros
# 191  192               Acacia dealbata      1  species        Acacia
# 192  193  Pyrus calleryana 'Cleveland'      1  species         Pyrus
#
#      percentage                       common_name
# 0      1.004903                               NaN
# 1      1.395549                               NaN
# 2      1.433267                               NaN
# 3      2.063689                               NaN
# 4      2.155289                               NaN
# ..          ...                               ...
# 188    0.002694                    Japanese Maple
# 189    0.002694                       Torrey Pine
# 190    0.002694
# 191    0.002694                     Silver Wattle
# 192    0.002694  Ornamental Pear Tree 'Cleveland'
#
# [193 rows x 7 columns]

# %%
# def set_value(genus):
#     name = genus
#     df = nodes_df.set_index('name')
#     id = df.at[name, 'id']
#     return id


# nodes_df['group'] = nodes_df['genus'].apply(set_value)

# nodes_df

# %%
nodes_df
# Out:
#       id                          name  count     Type         genus  \
# 0      1                     Cordyline    373    genus     Cordyline
# 1      2                     Ligustrum    518    genus     Ligustrum
# 2      3                          Acer    532    genus          Acer
# 3      4                      Maytenus    766    genus      Maytenus
# 4      5                         Ulmus    800    genus         Ulmus
# ..   ...                           ...    ...      ...           ...
# 188  189                Acer japonicum      1  species          Acer
# 189  190               Pinus torreyana      1  species         Pinus
# 190  191              Metrosideros spp      1  species  Metrosideros
# 191  192               Acacia dealbata      1  species        Acacia
# 192  193  Pyrus calleryana 'Cleveland'      1  species         Pyrus
#
#      percentage                       common_name
# 0      1.004903                               NaN
# 1      1.395549                               NaN
# 2      1.433267                               NaN
# 3      2.063689                               NaN
# 4      2.155289                               NaN
# ..          ...                               ...
# 188    0.002694                    Japanese Maple
# 189    0.002694                       Torrey Pine
# 190    0.002694
# 191    0.002694                     Silver Wattle
# 192    0.002694  Ornamental Pear Tree 'Cleveland'
#
# [193 rows x 7 columns]

# %%
nodes_df.to_csv('bubbles.csv')

# %%
def getNodeID(name):
    df = nodes_df.set_index('name')
    id = df.at[name, 'id']
    return id

getNodeID('Prunus sp')
# Out:
# 176

# %%
# links = []


# for i in range(len(nodes_df)):
#     element = nodes_df.loc[i]
#     if (element['Type'] == 'species'):
#         sourceGenus = element['genus']
        
#         sourceID = getNodeID(sourceGenus)
#         targetID = getNodeID(element['name'])
#         strength = 1
        
#         link = { 'source': sourceID, 'target': targetID, 'strength': strength };
#         links.append(link);
    
        
                            
# print(links)
# print(len(links))

# links = pd.DataFrame(links, columns = ['source', 'target'])

# %%
# links.to_csv('links.csv')

# %%
trees_genus_df = genus_df[genus_df['percentage'] >= 1]

trees_genus_df.reset_index(drop=True, inplace=True)

# %%
trees_genus_df.insert(0, 'id', value=trees_genus_df.index + 1)

# %%
# trees_genus_df[-1] = [17, "San Francisco's Trees", 5000, 100]
# trees_genus_df.index = df.index + 1  # shifting index
# trees_genus_df = trees_genus_df.sort_index() 

list_row = [26, "San Francisco's Trees", 2821, 100]
trees_genus_df.loc[len(trees_genus_df)] = list_row
# Out:
# /var/folders/5n/08myl3n11bn224bdxw_yfvjr0000gn/T/ipykernel_35095/1497002186.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trees_genus_df.loc[len(trees_genus_df)] = list_row

# %%
trees_genus_df
# Out:
#     id                  genus  count  percentage
# 0    1              Cordyline    373    1.004903
# 1    2              Cupressus    388    1.045315
# 2    3              Melaleuca    453    1.220432
# 3    4              Ligustrum    518    1.395549
# 4    5             Eriobotrya    525    1.414408
# 5    6                   Acer    532    1.433267
# 6    7             Eucalyptus    619    1.667655
# 7    8                  Pinus    639    1.721537
# 8    9                 Ginkgo    708    1.907430
# 9   10               Maytenus    766    2.063689
# 10  11                  Ulmus    800    2.155289
# 11  12               Corymbia    815    2.195700
# 12  13            Callistemon    859    2.314241
# 13  14                   Olea    873    2.351959
# 14  15                 Acacia   1100    2.963522
# 15  16                  Pyrus   1194    3.216768
# 16  17                Arbutus   1201    3.235627
# 17  18            Lophostemon   1727    4.652729
# 18  19               Magnolia   1862    5.016434
# 19  20          Tristaniopsis   1904    5.129587
# 20  21           Metrosideros   1939    5.223881
# 21  22            Pittosporum   2147    5.784256
# 22  23                  Ficus   2216    5.970149
# 23  24               Platanus   2757    7.427663
# 24  25                 Prunus   2821    7.600086
# 25  26  San Francisco's Trees   2821  100.000000

# %%
trees_genus_df.to_csv("genus_network.csv")

# %%
hopes = []


for i in range(len(trees_genus_df) - 1):
    element = trees_genus_df.loc[i]
       
#     sourceID = 17
    targetID = element['id']
        

    hope = { 'source': 26, 'target': targetID};
    hopes.append(hope);
    
        
                            
print(hopes)
print(len(hopes))

hopes_df = pd.DataFrame(hopes, columns = ['source', 'target'])
# Out:
# [{'source': 26, 'target': 1}, {'source': 26, 'target': 2}, {'source': 26, 'target': 3}, {'source': 26, 'target': 4}, {'source': 26, 'target': 5}, {'source': 26, 'target': 6}, {'source': 26, 'target': 7}, {'source': 26, 'target': 8}, {'source': 26, 'target': 9}, {'source': 26, 'target': 10}, {'source': 26, 'target': 11}, {'source': 26, 'target': 12}, {'source': 26, 'target': 13}, {'source': 26, 'target': 14}, {'source': 26, 'target': 15}, {'source': 26, 'target': 16}, {'source': 26, 'target': 17}, {'source': 26, 'target': 18}, {'source': 26, 'target': 19}, {'source': 26, 'target': 20}, {'source': 26, 'target': 21}, {'source': 26, 'target': 22}, {'source': 26, 'target': 23}, {'source': 26, 'target': 24}, {'source': 26, 'target': 25}]
# 25

# %%
hopes_df.to_csv('edges.csv')
